# %%
import pandas as pd

# %%
golden_glassdoor_reviews_df = pd.read_csv('golden_glassdoor_reviews.csv')

# %%
golden_glassdoor_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   review_id               600 non-null    int64
#  1   company                 600 non-null    object
#  2   employee_role           600 non-null    object
#  3   employee_detail         600 non-null    object
#  4   review_text             600 non-null    object
#  5   review_date             600 non-null    object
#  6   star_rating             600 non-null    float64
#  7   sentiment               600 non-null    int64
#  8   predicted_sentiment_m1  600 non-null    int64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 42.3+ KB

# %%
golden_glassdoor_reviews_df.iloc[397:402]
# Out:
#      review_id                     company  \
# 397   27353338                       TOTVS
# 398   79541035                       TOTVS
# 399   78459137  Sankhya Gestão de Negócios
# 400   26637627                       TOTVS
# 401   71789289                       TOTVS
#
#                                    employee_role  \
# 397                             Analista Suporte
# 398  Analista III de Desenvolvimento de Software
# 399                                   Estagiário
# 400                Analista De Saúde Ocupacional
# 401                          Analista De Suporte
#
#                            employee_detail  \
# 397                   Funcionário(a) atual
# 398  Funcionário(a) atual, mais de 10 anos
# 399                   Funcionário(a) atual
# 400                   Funcionário(a) atual
# 401   Funcionário(a) atual, mais de um ano
#
#                                            review_text         review_date  \
# ...

# %%
golden_glassdoor_reviews_df = pd.concat(
    [
        golden_glassdoor_reviews_df.iloc[:200].sample(85),
        golden_glassdoor_reviews_df.iloc[200:400].sample(85),
        golden_glassdoor_reviews_df.iloc[400:].sample(85),
    ]
)

# %%
golden_glassdoor_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 255 entries, 56 to 543
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   review_id               255 non-null    int64
#  1   company                 255 non-null    object
#  2   employee_role           255 non-null    object
#  3   employee_detail         255 non-null    object
#  4   review_text             255 non-null    object
#  5   review_date             255 non-null    object
#  6   star_rating             255 non-null    float64
#  7   sentiment               255 non-null    int64
#  8   predicted_sentiment_m1  255 non-null    int64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 19.9+ KB

# %%
golden_glassdoor_reviews_df["sentiment"].value_counts()
# Out:
# predicted_sentiment_m1
# 0    85
# 1    85
# 2    85
# Name: count, dtype: int64

# %%
golden_glassdoor_reviews_df.to_csv(
    f"golden_glassdoor_reviews.csv",
    index=False,
)
