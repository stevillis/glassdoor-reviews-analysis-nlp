# %% [markdown]
# # References
# - https://github.com/jessevig/bertviz?tab=readme-ov-file
# - https://colab.research.google.com/drive/1hXIQ77A4TYS4y3UthWF-Ci7V7vVUoxmQ?usp=sharing#scrollTo=-QnRteSLP0Hm

# %%
# !pip install bertviz

# %%
from transformers import AutoTokenizer, AutoModel, utils
from bertviz import model_view

# %%
utils.logging.set_verbosity_error()  # Suppress standard warnings

# %% [markdown]
# ## 1. Load BERTimbau model & tokenizer

# %%
model_type = "bert"
model_name = "neuralmind/bert-base-portuguese-cased"

# %%
model = AutoModel.from_pretrained(model_name, output_attentions=True)
# Out:
# WARNING:tensorflow:From c:\venvs\venv_sent_analysis\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %% [markdown]
# ## 2. Prepare input text

# %%
input_text = (
    "Empresa parceira, apoia todos os colaboradores, oportunidade de crescimento."
)

# %% [markdown]
# ## 3. Tokenize and get model outputs

# %%
inputs = tokenizer.encode(input_text, return_tensors="pt")

# %%
outputs = model(inputs)

# %%
attention = outputs[-1]  # Retrieve attention from model outputs

# %% [markdown]
# ## 4. Generate visualization

# %%
tokens = tokenizer.convert_ids_to_tokens(
    inputs[0]
)  # Convert input ids to token strings

# %%
model_view(attention, tokens)  # Display model view
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>
#
#         <div id="bertviz-1d7ee33803094100ba976be5eb461d68" style="font-family:'Helvetica Neue', Helvetica, Arial, sans-serif;">
#             <span style="user-select:none">
#
#             </span>
#             <div id='vis'></div>
#         </div>
